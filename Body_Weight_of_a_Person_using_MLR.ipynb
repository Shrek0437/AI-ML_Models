# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrek0437/AI-ML_Models/blob/main/Body_Weight_of_a_Person_using_MLR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import Ridge
model = Ridge(alpha=1.0)

# %%
data = {
    'Weight': [79, 69, 73, 95, 82, 55, 69, 71, 64, 69],
    'Height': [1.80, 1.68, 1.82, 1.70, 1.87, 1.55, 1.50, 1.78, 1.67, 1.64],
    'Age': [35, 39, 25, 60, 27, 18, 89, 42, 16, 52],
    'Gender': ['Male', 'Male', 'Male', 'Male', 'Male',
               'Female', 'Female', 'Female', 'Female', 'Female']
}

df = pd.DataFrame(data)
df
# Out:
#    Weight  Height  Age  Gender
# 0      79    1.80   35    Male
# 1      69    1.68   39    Male
# 2      73    1.82   25    Male
# 3      95    1.70   60    Male
# 4      82    1.87   27    Male
# 5      55    1.55   18  Female
# 6      69    1.50   89  Female
# 7      71    1.78   42  Female
# 8      64    1.67   16  Female
# 9      69    1.64   52  Female

# %%
x = df.iloc[:,1:]
y = df.iloc[:,0:1]
display(x,y)
# Out:
#    Height  Age  Gender
# 0    1.80   35    Male
# 1    1.68   39    Male
# 2    1.82   25    Male
# 3    1.70   60    Male
# 4    1.87   27    Male
# 5    1.55   18  Female
# 6    1.50   89  Female
# 7    1.78   42  Female
# 8    1.67   16  Female
# 9    1.64   52  Female
#    Weight
# 0      79
# 1      69
# 2      73
# 3      95
# 4      82
# 5      55
# 6      69
# 7      71
# 8      64
# 9      69

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=50)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
print(y_pred)
print(y_test)
# Out:
# [[78.24765478]
#  [71.17091932]
#  [60.23414634]]
#    Weight
# 7      71
# 8      64
# 6      69

# %%
min_new = float(input("Enter your Height: "))
predicted_weight = model.predict(np.array([[min_new]]))
print(f"Predicted weight for {min_new} cms of Height: {predicted_weight[0]}")
# Out:
# Enter your Height: 1.5
# Predicted weight for 1.5 cms of Height: [60.23414634]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#EVALUATION METRICS
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R^2 Score: {r2:.2f}")
# Out:
# Mean Absolute Error (MAE): 7.73
# Mean Squared Error (MSE): 60.26
# Root Mean Squared Error (RMSE): 7.76
# R^2 Score: -5.95

# %% [markdown]
# You are already performing multi-linear regression by using 'Height', 'Age', and the one-hot encoded 'Gender' as features to predict 'Weight'.

# %%
# The independent variables (features) are Height, Age, and Gender
x = df[['Height', 'Age', 'Gender']]

# The dependent variable (target) is Weight
y = df['Weight']

# One-hot encode the 'Gender' column
x = pd.get_dummies(x, columns=['Gender'], drop_first=True)

display(x, y)
# Out:
#    Height  Age  Gender_Male
# 0    1.80   35         True
# 1    1.68   39         True
# 2    1.82   25         True
# 3    1.70   60         True
# 4    1.87   27         True
# 5    1.55   18        False
# 6    1.50   89        False
# 7    1.78   42        False
# 8    1.67   16        False
# 9    1.64   52        False
# 0    79
# 1    69
# 2    73
# 3    95
# 4    82
# 5    55
# 6    69
# 7    71
# 8    64
# 9    69
# Name: Weight, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=50)

model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

display(y_pred)
display(y_test)
# Out:
# array([74.30146881, 55.4650861 , 86.0708676 ])
# 7    71
# 8    64
# 6    69
# Name: Weight, dtype: int64

# %%
import numpy as np
import pandas as pd

height = float(input("Enter Height: "))
age = int(input("Enter Age: "))
gender = input("Enter Gender (Male/Female): ")

new_data = pd.DataFrame([[height, age, 0]], columns=['Height', 'Age', 'Gender_Male'])
if gender.lower() == 'male':
    new_data['Gender_Male'] = 1

predicted_weight = model.predict(new_data)
print(f"Predicted weight for Height: {height}, Age: {age}, Gender: {gender}: {predicted_weight[0]:.2f}")
# Out:
# Enter Height: 1.8
# Enter Age: 17
# Enter Gender (Male/Female): Male
# Predicted weight for Height: 1.8, Age: 17, Gender: Male: 70.15

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

#EVALUATION METRICS
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R^2 Score: {r2:.2f}")
# Out:
# Mean Absolute Error (MAE): 9.64
# Mean Squared Error (MSE): 125.05
# Root Mean Squared Error (RMSE): 11.18
# R^2 Score: -13.43
